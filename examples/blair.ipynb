# %% [markdown]
# ### Example from "A gentle introduction to computer vision-based specimen classification in ecological datasets" by Jarret Blair
# Based on data from: https://github.com/Jarrett-Blair/Intro-to-CV-for-Ecologists/tree/main

# %%
# !mkdir -p blair \
    && cd blair \
    && wget https://github.com/Jarrett-Blair/Intro-to-CV-for-Ecologists/raw/refs/heads/main/Data/Images.zip \
    && unzip Images.zip \
    && rm Images.zip \
    && mv Images/training train \
    && mv Images/testing test \
    && rm -rf Images
# Out:
# --2026-01-16 19:45:39--  https://github.com/Jarrett-Blair/Intro-to-CV-for-Ecologists/raw/refs/heads/main/Data/Images.zip
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Jarrett-Blair/Intro-to-CV-for-Ecologists/refs/heads/main/Data/Images.zip [following]
# --2026-01-16 19:45:39--  https://raw.githubusercontent.com/Jarrett-Blair/Intro-to-CV-for-Ecologists/refs/heads/main/Data/Images.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32191966 (31M) [application/zip]
# Saving to: ‘Images.zip’
#
# Images.zip          100%[===================>]  30.70M  55.7MB/s    in 0.6s
#
# ...

# %% [markdown]
# # Single node training

# %%
# Remove `--cache CUDA` and/or lower batch_size if you have limited VRAM
# !cd blair \
    && rm -rf blair_model \
    && uv -qq run --no-sync mt_htrain -i train -o . \
        --name blair_model \
        --model efficientnet_v2_s \
        --size 128 \
        --batch_size 32 \
        --epochs 5 \
        --warmup_epochs 1 \
        --lr 0.01 \
        --class_weighted \
        --loss_weights 1 1 \
        --cache CUDA \
        --verbose \
    && uv -qq run mt_hpredict -i test -o blair_model \
        --weights blair_model/weights/last.pt \
        --verbose \
    && uvx -qq --from git+https://github.com/GuillaumeMougeot/mini_metrics.git mm_metrics \
        --file blair_model/predict/mini_metric.csv
# Out:
# {'input': '/home/asger/Repositories/mini_trainer/examples/blair/train', 'output': '/home/asger/Repositories/mini_trainer/examples/blair', 'epochs': 5, 'size': 128, 'name': 'blair_model', 'device': 'cuda:0', 'dtype': 'float16', 'ema': False, 'builder': 'mini_trainer.hierarchical.integration.HierarchicalBuilder', 'spec_model_dataloader_kwargs': {'species': True, 'levels': 2}, 'model_builder_kwargs': {'model_type': 'efficientnet_v2_s', 'fine_tune': False, 'hidden': True, 'droprate': 0.1, 'normalized': True, 'cls': 'mini_trainer.hierarchical.model.HierarchicalClassifier'}, 'dataloader_builder_kwargs': {'batch_size': 32, 'train_proportion': 0.9, 'resample': False, 'cache': 'CUDA'}, 'optimizer_builder_kwargs': {'optimizer_cls': 'mini_trainer.training.muon.MuonAuxAdamW', 'lr': 0.01, 'weight_decay': 0.01}, 'ema_builder_kwargs': {'epoch_halflife': 1.5, 'update_rate': 4, 'temperature': 1.0, 'distill_start': 2.0}, 'criterion_builder_kwargs': {'weighted': True, 'label_smoothing': 0.1, 'weights':
# ...

# %% [markdown]
# # Dual node DGX Spark training
# Requirements:
#
# * Establish direct QSFP: https://build.nvidia.com/spark/connect-two-sparks - **NOTE:** You must assign static IPs and configure SSH aliases in ~/.ssh/config
# * Install and configure NCCL: https://build.nvidia.com/spark/nccl

# %%
# OBS: Replace `-w spkc` with the SSH host alias used for MPI/NCCL with the second DGX Spark/Node
# !cd blair \
    && rm -rf blair_model \
    && uv -qq run --no-sync bash ../../ddp/spark.sh -w spkc -m mini_trainer.hierarchical.train -i train -o . \
        --name blair_model \
        --model efficientnet_v2_s \
        --size 128 \
        --batch_size 32 \
        --epochs 5 \
        --warmup_epochs 1 \
        --lr 0.01 \
        --class_weighted \
        --loss_weights 1 1 \
        --cache CUDA \
        --verbose \
    && uv -qq run mt_hpredict -i test -o blair_model \
        --weights blair_model/weights/last.pt \
        --verbose \
    && uvx -qq --from git+https://github.com/GuillaumeMougeot/mini_metrics.git mm_metrics \
        --file blair_model/predict/mini_metric.csv
# Out:
# [Launcher] Resolving network topology...
# [Launcher] Establishing ephemeral NFS mount over QSFP...
# [Launcher] Verifying environment synchronization...
# [Launcher] Testing PyTorch import on worker node...
#  PyTorch 2.12.0+cu130 loaded on worker.
# [Launcher] Spawning worker on spkc (192.168.100.11)...
# [Launcher] Spawning master locally (192.168.100.10)...
# spark-967b:380569:380569 [0] NCCL INFO ENV/Plugin: Could not find: libnccl-env.so
# spark-967b:380569:380569 [0] NCCL INFO NCCL_SOCKET_IFNAME set by environment to enp1s0f1np1
# spark-967b:380569:380569 [0] NCCL INFO Bootstrap: Using enp1s0f1np1:192.168.100.10<0>
# spark-967b:380569:380569 [0] NCCL INFO cudaDriverVersion 13000
# spark-967b:380569:380569 [0] NCCL INFO NCCL version 2.29.7+cuda13.2
# spark-967b:380569:380569 [0] NCCL INFO NCCL git version stable b81d6a5a3
# spark-967b:380569:380569 [0] NCCL INFO Comm config Blocking set to 1
# spark-967b:380569:380569 [0] NCCL INFO NET/Plugin: Could not find: libnccl-net.so
# ...

# %% [markdown]
# # Inference

# %%
# Test that all species can be resolved properly (they can)
import os

from mini_trainer.integrations import name_to_id, resolve_id

sp2cls = {}

for species in os.listdir("blair/train"):
    id, rank, confidence = name_to_id(species)
    result = resolve_id(id)
    sp2cls[species] = result

classes = {}
for cls in sp2cls.values():
    for rank, (id, name) in cls.items():
        if rank not in classes:
            classes[rank] = []
        classes[rank].append(name)
classes = {r: sorted(set(cs)) for r, cs in classes.items()}
print("Number of classes at rank:")
for rank, cs in classes.items():
    print(f"{rank:<10}={len(cs):>4}")
classes = {r: cs for r, cs in classes.items() if len(cs) > 1}
print("\nIncluded ranks:")
print(", ".join(classes))
# Out:
# Number of classes at rank:
# species   =  25
# genus     =  15
# family    =   1
# order     =   1
# class     =   1
# phylum    =   1
# kingdom   =   1
#
# Included ranks:
# species, genus

# %% [markdown]
# # Manual model load

# %%
import json

import torch

from mini_trainer.builders import BaseBuilder

with open("blair/blair_model/class_spec.json") as f:
    class_spec = json.load(f)

cls2idx = class_spec["cls2idx"]
idx2cls = {v: k for k, v in cls2idx.items()}

device, dtype = torch.device("cuda:0"), torch.float32

model, mproc = BaseBuilder.build_model(weights="blair/blair_model/weights/best.pt", hidden=512, device=device, dtype=dtype)
model.eval()
pass
# Out:
# /home/asger/Repositories/mini_trainer/mini_trainer/classifier.py:486: UserWarning: Model configuration option hidden overriden by value stored in config: 1280 ==> True
#   warnings.warn(f"Model configuration option {k} overriden by value stored in config: {kwargs[k]} ==> {v}", UserWarning)

# %%
from matplotlib import pyplot as plt
from matplotlib.axes import Axes
from PIL import Image

from mini_trainer.data.io import LazyDataset
from mini_trainer.logging import BaseResultCollector

genera = classes["genus"][:5]
species = []
for k, v in sp2cls.items():
    g = v["genus"][1]
    if g not in genera:
        continue
    genera.remove(g)
    species.append(k)

images = []
labels = []
for sp in species:
    spcls = sp2cls[sp]
    s, g = sp, spcls["genus"][1]
    dir = os.path.join("blair", "test", sp)
    ims = [os.path.join(dir, f) for f in os.listdir(dir)][:10]
    images.extend(ims)
    labels.extend([(s, g)] * len(ims))

ds = LazyDataset(mproc, images)

fig, axs = plt.subplots(5, 10, figsize=(7.5, 5))

for i, ax in enumerate(axs.flatten()):
    tim = ds[i]
    with torch.inference_mode():
        prediction = model(tim.unsqueeze(0).to(device))[0]
    pred_cls = idx2cls[prediction.argmax().item()]
    label_cls = labels[i][0]
    correct = pred_cls == label_cls
    if not isinstance(ax, Axes):
        raise TypeError()
    ax.imshow(Image.open(images[i]))
    ax.set_title(
        "\n".join(pred_cls.split(" ")[:2]), pad=0, y=1.025, fontdict={"fontsize": 5, "fontweight": "bold" if correct else "normal"}
    )
    ax.axis("off")

plt.tight_layout(pad=0)
plt.show()
# Out:
# On-the-fly data loading enabled (no cache).

# %% [markdown]
# *The manual inference for this demo is not implemented in the most optimal way for sake of simplicity*

# %%
results = BaseResultCollector(model, idx2cls, cls2idx, True)

species = list(sp2cls.keys())
images = []
labels = []
for sp in species:
    spcls = sp2cls[sp]
    s, g = sp, spcls["genus"][1]
    dir = os.path.join("blair", "test", sp)
    ims = [os.path.join(dir, f) for f in os.listdir(dir)][:10]
    images.extend(ims)
    labels.extend([(s, g)] * len(ims))

ds = LazyDataset(mproc, images)
for b in range(len(ds) // 5):
    bis = list(range(b * 5, b * 5 + 5))
    with torch.inference_mode():
        predictions = model(torch.stack([ds[i] for i in bis]).to(device))[0]
    bims = [images[i] for i in bis]
    results.collect(bims, predictions, labels=[labels[i][0] for i in bis])
results.evaluate()
pass
# Out:
# On-the-fly data loading enabled (no cache).
# 6|1| | | | | | | | | | | | | | | | | | | | | | |
#  |8| | | |1| | | | | | | | | | | | | |1| | | | |
#  | |5| | | | | | | |2| | | | | | | | | | | | | |3
#  | | |4| | | | | | | | | | | | | | |2|4| | | | |
#  | | |1|5| | |2| | | | | |1| | | | | |1| | | | |
# 1| | | | |9| | | | | | | | | | | | | | | | | | |
#  | | | | | |9| | | | | | | |1| | | | | | | | | |
#  | | | | | | |6| | | | | | | | | | | | |2| |2| |
#  | | | | | | | | | | | | | | | | | |2|1|1|4|2| |
#  | | | | | | | | |2|1| | | |6| | | | | | | | | |1
#  | | | | | | | | |1|5|1| | |2| | | | | | | | | |1
#  | | | | | | | | | | |8| | | | | | | | | | |1| |1
#  | | | |1| | |2|1| | | | |2|1|2| | | | | | |1| |
#  | | | | | | | |1| | | | |3| |5| | | | | | |1| |
#  | | | | | | | |1| | | | |1|2|4| | | | | | |2| |
#  | | | | | | | |2| | | | | | |5| | | | |1| |2| |
#  |1| | | | | | | | |1| | | | | |1| | | | | | | |7
#  | | | | | | | | | | | | | | | | |5| | | | | | |3
# ...
